# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium

from geopy.geocoders import Nominatim

# %matplotlib inline

origin = [41.5511, -8.428]

filepath = 'data/Traffic_Incidents_Braga_Until_20190228.csv'

cols = ['description', 'cause_of_incident', 'from_road', 'to_road',
       'affected_roads', 'incident_category_desc', 'magnitude_of_delay_desc',
       'length_in_meters', 'delay_in_seconds', 'incident_date']

dtypes = {'description': 'category',
 'cause_of_incident': 'category',
 'from_road': 'category',
 'to_road': 'category',
 'affected_roads': 'category',
 'incident_category_desc': 'category',
 'magnitude_of_delay_desc': 'category',
 'length_in_meters': 'uint16',
 'delay_in_seconds': 'uint16',
 'incident_date': 'category'}

df = pd.read_csv(filepath, usecols=cols, dtype=dtypes, parse_dates=['incident_date'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45714 entries, 0 to 45713
# Data columns (total 10 columns):
# description                45714 non-null category
# cause_of_incident          30 non-null category
# from_road                  45714 non-null category
# to_road                    45714 non-null category
# affected_roads             22641 non-null category
# incident_category_desc     45714 non-null category
# magnitude_of_delay_desc    45714 non-null category
# length_in_meters           45714 non-null uint16
# delay_in_seconds           45714 non-null uint16
# incident_date              45714 non-null datetime64[ns]
# dtypes: category(7), datetime64[ns](1), uint16(2)
# memory usage: 988.1 KB

# %%
def typecast_objects(gl_obj):
    gl_obj = gl_obj.apply(lambda x: x.str.strip())
    gl_obj = gl_obj.apply(lambda x: x.str.lower())
    
    converted_obj = pd.DataFrame()
    
    for col in gl_obj.columns:
        num_unique_values = len(gl_obj[col].unique())
        num_total_values = len(gl_obj[col])
        if num_unique_values / num_total_values < 0.5:
            converted_obj.loc[:, col] = gl_obj[col].astype('category')
        else:
            converted_obj.loc[:, col] = gl_obj[col]
    
    return converted_obj


def downcast(df):
    df_int = df.select_dtypes(include=['int'])
    converted_int = df_int.apply(pd.to_numeric, downcast='unsigned')

    df_obj = df.select_dtypes(include=['object'])
    converted_obj = typecast_objects(df_obj)

    df[converted_int.columns] = converted_int
    df[converted_obj.columns] = converted_obj
    
    return df


def get_dtypes(df):
    dtypes = df.dtypes

    colnames = dtypes.index
    types = [i.name for i in dtypes.values]

    return dict(zip(colnames, types))

# %%
df = df.sort_values(by=['incident_date'])
df = df.reset_index(drop=True)

# %%
df.sample(10)
# Out:
#               description cause_of_incident  \
# 6023   stationary traffic               NaN
# 64           slow traffic               NaN
# 43706              closed               NaN
# 39866        slow traffic               NaN
# 32350              closed               NaN
# 37346              closed               NaN
# 20643  stationary traffic               NaN
# 2389   stationary traffic               NaN
# 39693       bridge closed               NaN
# 19962  stationary traffic               NaN
#
#                                                from_road  \
# 6023                                           São Vítor
# 64                                         Rua do Caires
# 43706             Avenida Doutor Francisco Salgado Zenha
# 39866   Avenida General Norton De Matos (Braga-Circular)
# 32350             Avenida Doutor Francisco Salgado Zenha
# 37346             Avenida Doutor Francisco Salgado Zenha
# 20643                      Avenida António Gomes Pereira
# 2389   Rua Feliciano Ramos (N101) / Rua Cónego Lucian...
# 39693     Avenida General Carrilho Da Silva Pinto (N103)
# 19962            Rotunda da Associação Jurídica de Braga
#
#                                    to_road affected_roads  \
# 6023           Avenida Padre Júlio Fragata            NaN
# 64                                    N101            NaN
# 43706                 Avenida Robert Smith            NaN
# 39866  N101 (Braga Norte) (Braga-Circular)            NaN
# 32350                 Avenida Robert Smith            NaN
# 37346                 Avenida Robert Smith            NaN
# 20643      Autoestrada Esposende-Guimarães            N14
# 2389                       Rua Irmãos Roby            NaN
# 39693    Braga-Circular (São Vítor) (N103)           N103
# 19962                 Largo de Santa Tecla            NaN
#
#       incident_category_desc magnitude_of_delay_desc  length_in_meters  \
# 6023                     Jam                   Major               320
# 64                       Jam                   Minor               910
# 43706            Road Closed               Undefined                88
# 39866                    Jam                   Minor               577
# 32350            Road Closed               Undefined                88
# 37346            Road Closed               Undefined                88
# 20643                    Jam                Moderate              1010
# 2389                     Jam                   Major               530
# 39693            Road Closed               Undefined               381
# 19962                    Jam                   Major               400
#
#        delay_in_seconds           incident_date
# 6023                143 2018-09-07 18:03:53.771
# 64                   56 2018-07-24 18:02:04.354
# 43706                 0 2019-02-21 06:44:58.994
# 39866                32 2019-02-06 18:24:59.614
# 32350                 0 2018-12-04 20:07:08.971
# 37346                 0 2019-01-27 12:44:59.665
# 20643               238 2018-10-17 14:47:20.921
# 2389                185 2018-08-24 22:23:52.838
# 39693                 0 2019-02-06 00:04:59.085
# 19962               309 2018-10-15 08:07:20.884
