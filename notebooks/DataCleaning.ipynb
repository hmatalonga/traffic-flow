# %%
import numpy as np
import pandas as pd
import pickle

# %%
# Flow
filepath = 'data/Traffic_Flow_Braga_With_Cordinates_20190228.csv'

cols = ['road_num', 'road_name', 'functional_road_class_desc',
       'current_speed', 'free_flow_speed', 'speed_diff', 'current_travel_time',
       'free_flow_travel_time', 'time_diff', 'creation_date', 'began_lat',
       'end_lat', 'began_long', 'end_long']

dtypes = {'road_num': 'uint8',
 'road_name': 'category',
 'functional_road_class_desc': 'category',
 'current_speed': 'uint8',
 'free_flow_speed': 'uint8',
 'speed_diff': 'uint8',
 'current_travel_time': 'int64',
 'free_flow_travel_time': 'uint16',
 'time_diff': 'int64',
 'began_lat': 'float32',
 'end_lat': 'float32',
 'began_long': 'float32',
 'end_long': 'float32'}

flow = pd.read_csv(filepath, usecols=cols, dtype=dtypes, parse_dates=['creation_date'])

# %%
# Incidents - we are removing the speedways away from the city center and main flow roads
filepath = 'data/Traffic_Incidents_Braga_Only_Route.csv'

cols = ['description', 'cause_of_incident', 'from_road', 'to_road',
       'affected_roads', 'incident_category_desc', 'magnitude_of_delay_desc',
       'length_in_meters', 'delay_in_seconds', 'incident_date', 'latitude', 'longitude']

dtypes = {'description': 'category',
 'cause_of_incident': 'category',
 'from_road': 'category',
 'to_road': 'category',
 'affected_roads': 'category',
 'incident_category_desc': 'category',
 'magnitude_of_delay_desc': 'category',
 'length_in_meters': 'uint16',
 'delay_in_seconds': 'uint16',
 'latitude': 'float32',
 'longitude': 'float32'}

incidents = pd.read_csv(filepath, usecols=cols, dtype=dtypes, parse_dates=['incident_date'])

# %%
# Data cleaning
flow = flow.sort_values(by=['creation_date', 'road_num'])
flow = flow.reset_index(drop=True)

incidents = incidents.sort_values(by=['incident_date'])
incidents = incidents.reset_index(drop=True)

# %%
# Feature engineering
flow['date'] = flow['creation_date'].dt.strftime('%Y-%m-%d')
flow['datetime'] = flow['creation_date'].dt.strftime('%Y-%m-%d %H')

incidents['datetime'] = incidents['incident_date'].dt.strftime('%Y-%m-%d %H')
incidents['incident_date'] = incidents['incident_date'].dt.strftime('%Y-%m-%d %H:%M')

# %%
incidents.head()
# Out:
#           description cause_of_incident  \
# 0  stationary traffic               NaN
# 1  stationary traffic               NaN
# 2  stationary traffic               NaN
# 3     queuing traffic               NaN
# 4  stationary traffic               NaN
#
#                                 from_road  \
# 0                      Rua de São Gonçalo
# 1         Rua 5 De Julho / Rua do Outeiro
# 2         Rua do Conselheiro Bento Miguel
# 3            Avenida João Paulo II (N103)
# 4  Avenida de Sequeira / Rua de São Pedro
#
#                                              to_road affected_roads  \
# 0  Largo de São Francisco (N101) / Praça da Repúb...            NaN
# 1                         Avenida São Lourenço (N14)            NaN
# 2                                Rua Feliciano Ramos           N101
# 3  Rua Cónego Luciano Afonso dos Santos (N101) / ...            NaN
# 4             Avenida de Sequeira / Rua de São Pedro           N103
#
#   incident_category_desc magnitude_of_delay_desc  length_in_meters  \
# 0                    Jam                   Major               200
# 1                    Jam                Moderate               350
# 2                    Jam                Moderate               300
# 3                    Jam                Moderate               590
# 4                    Jam                   Major               630
#
#    delay_in_seconds     incident_date   latitude  longitude       datetime
# 0               197  2018-07-24 14:58  41.551788   -8.42116  2018-07-24 14
# 1               168  2018-07-24 16:47  41.514069   -8.45438  2018-07-24 16
# 2               141  2018-07-24 16:47  41.557812   -8.41734  2018-07-24 16
# 3               127  2018-07-24 16:47  41.555019   -8.40697  2018-07-24 16
# 4               228  2018-07-24 16:47  41.537361   -8.45229  2018-07-24 16

# %%
flow.head()
# Out:
#    road_num             road_name functional_road_class_desc  current_speed  \
# 0         1  Avenida da Liberdade             Secondary Road             25
# 1         1  Avenida da Liberdade             Secondary Road             25
# 2         2       Avenida Central             Secondary Road             25
# 3         3         Rua de Caires      Local Connecting Road             25
# 4         4             N14 Bosch           Other Major Road             32
#
#    free_flow_speed  speed_diff  current_travel_time  free_flow_travel_time  \
# 0               25           0                  124                    124
# 1               25           0                  124                    124
# 2               25           0                  124                    124
# 3               37          12                   54                     36
# 4               47          15                   70                     48
#
#    time_diff       creation_date  began_lat    end_lat  began_long  end_long  \
# 0          0 2018-07-24 14:58:54  41.550884  41.542164   -8.422812 -8.417782
# 1          0 2018-07-24 14:58:55  41.550884  41.542164   -8.422812 -8.417782
# 2          0 2018-07-24 14:58:55  41.559689  41.553974   -8.446710 -8.438541
# 3         18 2018-07-24 14:58:55  41.544514  41.549107   -8.433262 -8.433573
# 4         22 2018-07-24 14:58:55  41.539219  41.526821   -8.433685 -8.447850
#
#          date       datetime
# 0  2018-07-24  2018-07-24 14
# 1  2018-07-24  2018-07-24 14
# 2  2018-07-24  2018-07-24 14
# 3  2018-07-24  2018-07-24 14
# 4  2018-07-24  2018-07-24 14

# %%
# Weather
filepath = 'data/Weather_Braga_Until_20190228.csv'

cols = ['weather_description', 'temperature', 'atmospheric_pressure',
        'humidity', 'wind_speed', 'cloudiness', 'current_luminosity',
        'sunrise', 'sunset', 'creation_date']

dtypes = {'weather_description': 'category',
 'temperature': 'uint8',
 'atmospheric_pressure': 'uint16',
 'humidity': 'uint8',
 'wind_speed': 'uint8',
 'cloudiness': 'uint8',
 'current_luminosity': 'category'}

weather = pd.read_csv(filepath, usecols=cols, parse_dates=['sunrise', 'sunset', 'creation_date'])

# %%
m = {
    'nuvens quebrados': 'algumas nuvens',
    'nuvens quebradas': 'algumas nuvens',
    'nuvens dispersas': 'algumas nuvens',
    'céu pouco nublado': 'algumas nuvens',
    'neblina': 'névoa',
    'chuva leve': 'chuva fraca',
    'garoa fraca': 'chuva fraca',
    'chuva': 'chuva moderada',
    'chuva de intensidade pesada': 'chuva intensa',
    'chuva de intensidade pesado': 'chuva intensa',
    'trovoada com chuva leve': 'trovoada',
    'trovoada com chuva': 'trovoada',
}
weather['weather_description'] = weather['weather_description'].replace(m)

# %%
# Feature engineering
weather['datetime'] = weather['creation_date'].dt.strftime('%Y-%m-%d %H')

# %%
holidays = pd.read_csv('data/holidays.csv')
flow = pd.merge(flow, holidays, how='left', on='date')
flow = pd.merge(flow, weather, how='left', on='datetime')
incidents = pd.merge(incidents, weather, how='left', on='datetime')

# %%
flow['holiday_name'] = flow['holiday_name'].fillna(0)
flow['holiday_flag'] = [0 if x == 0 else 1 for x in flow['holiday_name']]
flow['datetime'] = pd.to_datetime(flow['datetime'])

# %%
flow = flow.drop(['date', 'datetime', 'creation_date_y', 'holiday_name'], axis=1)
flow = flow.rename(columns={'creation_date_x': 'creation_date'})

# %%
flow.head()
# Out:
#    road_num             road_name functional_road_class_desc  current_speed  \
# 0         1  Avenida da Liberdade             Secondary Road             25
# 1         1  Avenida da Liberdade             Secondary Road             25
# 2         2       Avenida Central             Secondary Road             25
# 3         3         Rua de Caires      Local Connecting Road             25
# 4         4             N14 Bosch           Other Major Road             32
#
#    free_flow_speed  speed_diff  current_travel_time  free_flow_travel_time  \
# 0               25           0                  124                    124
# 1               25           0                  124                    124
# 2               25           0                  124                    124
# 3               37          12                   54                     36
# 4               47          15                   70                     48
#
#    time_diff       creation_date  ...  weather_description  temperature  \
# 0          0 2018-07-24 14:58:54  ...       algumas nuvens         21.0
# 1          0 2018-07-24 14:58:55  ...       algumas nuvens         21.0
# 2          0 2018-07-24 14:58:55  ...       algumas nuvens         21.0
# 3         18 2018-07-24 14:58:55  ...       algumas nuvens         21.0
# 4         22 2018-07-24 14:58:55  ...       algumas nuvens         21.0
#
#    atmospheric_pressure  humidity wind_speed  cloudiness  current_luminosity  \
# 0                1016.0      77.0        5.0        20.0               LIGHT
# 1                1016.0      77.0        5.0        20.0               LIGHT
# 2                1016.0      77.0        5.0        20.0               LIGHT
# 3                1016.0      77.0        5.0        20.0               LIGHT
# 4                1016.0      77.0        5.0        20.0               LIGHT
#
#               sunrise              sunset  holiday_flag
# 0 2018-07-24 05:21:06 2018-07-24 19:58:50             0
# 1 2018-07-24 05:21:06 2018-07-24 19:58:50             0
# 2 2018-07-24 05:21:06 2018-07-24 19:58:50             0
# 3 2018-07-24 05:21:06 2018-07-24 19:58:50             0
# 4 2018-07-24 05:21:06 2018-07-24 19:58:50             0
#
# [5 rows x 24 columns]

# %%
flow.to_csv('data/flow.csv', index=False)

# %%
incidents.to_csv('data/incidents.csv', index=False)

# %%
weather.to_csv('data/weather.csv', index=False)

# %%
def cache_dtypes(df, ignored=[]):
    dtypes = df.drop(ignored, axis=1).dtypes
    dtypes_col = dtypes.index
    dtypes_type = [i.name for i in dtypes.values]
    
    return dict(zip(dtypes_col, dtypes_type))


def save_dtypes(dtypes, path):
    with open(path, 'wb') as handle:
        pickle.dump(dtypes, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print(path, 'created!')
